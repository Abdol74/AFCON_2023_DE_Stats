# %%
import pandas as pd 
from statsbombpy import sb

# %%
# !pip install statsbombpy
# Out:
# ...
#   Using cached statsbombpy-1.13.0-py3-none-any.whl (16 kB)
# ...
#      |████████████████████████████████| 302 kB 10.1 MB/s eta 0:00:01
# ...
#   Using cached inflect-7.2.0-py3-none-any.whl (34 kB)
# ...
#   Using cached requests_cache-1.2.0-py3-none-any.whl (61 kB)
# ...
#   Using cached typeguard-4.2.1-py3-none-any.whl (34 kB)
# ...
#   Using cached cattrs-23.2.3-py3-none-any.whl (57 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# ...
#   Using cached url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# ...

# %%
matches = sb.matches(competition_id=1267, season_id=107)
# Out:
# /home/abdol/.local/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
matches.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'competition', 'season',
#        'home_team', 'away_team', 'home_score', 'away_score', 'match_status',
#        'match_status_360', 'last_updated', 'last_updated_360', 'match_week',
#        'competition_stage', 'stadium', 'referee', 'home_managers',
#        'away_managers', 'data_version', 'shot_fidelity_version',
#        'xy_fidelity_version'],
#       dtype='object')

# %%
matches.to_csv('matches_csv')

# %%
matches
# Out:
#     match_id  match_date      kick_off                      competition  \
# 0    3923881  2024-02-11  22:00:00.000  Africa - African Cup of Nations
# 1    3923880  2024-02-10  22:00:00.000  Africa - African Cup of Nations
# 2    3922838  2024-02-07  22:00:00.000  Africa - African Cup of Nations
# 3    3922837  2024-02-07  19:00:00.000  Africa - African Cup of Nations
# 4    3922242  2024-01-29  22:00:00.000  Africa - African Cup of Nations
# 5    3922239  2024-01-28  19:00:00.000  Africa - African Cup of Nations
# 6    3922659  2024-02-03  19:00:00.000  Africa - African Cup of Nations
# 7    3922658  2024-02-03  22:00:00.000  Africa - African Cup of Nations
# 8    3922244  2024-01-30  19:00:00.000  Africa - African Cup of Nations
# 9    3922356  2024-02-02  22:00:00.000  Africa - African Cup of Nations
# 10   3922321  2024-02-02  19:00:00.000  Africa - African Cup of Nations
# 11   3922237  2024-01-27  19:00:00.000  Africa - African Cup of Nations
# ...

# %%
events = sb.events(match_id=3920385)
# Out:
# /home/abdol/.local/lib/python3.8/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_recovery_failure', 'block_deflection', 'block_offensive',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_other',
#        'clearance_right_foot', 'counterpress', 'dribble_nutmeg',
#        'dribble_outcome', 'duel_outcome', 'duel_type', 'duration',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_penalty', 'foul_committed_type', 'foul_won_defensive',
#        'foul_won_penalty', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_technique',
#        'goalkeeper_type', 'id', 'index', 'interception_outcome', 'location',
#        'match_id', 'minute', 'off_camera', 'out', 'pass_aerial_won',
#        'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
# ...
